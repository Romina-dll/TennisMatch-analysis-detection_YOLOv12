# %% [markdown]
# <a href="https://colab.research.google.com/github/Romina-dll/TennisMatch-analysis-detection_YOLOv12/blob/main/Tennis_Ball_Detector_training.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install roboflow
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 91.8/91.8 kB 7.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 6.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 22.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 93.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 112.1 MB/s eta 0:00:00
# ...
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.13.0.90
#     Uninstalling opencv-python-headless-4.13.0.90:
#       Successfully uninstalled opencv-python-headless-4.13.0.90
#   Attempting uninstall: idna
#     Found existing installation: idna 3.11
#     Uninstalling idna-3.11:
#       Successfully uninstalled idna-3.11
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 29.5 MB/s eta 0:00:00
# ...

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="LEgFsuwltOCyDyeSoRWH")
project = rf.workspace("viren-dhanwani").project("tennis-ball-detection")
version = project.version(6)
dataset = version.download("yolov5")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to tennis-ball-detection-6 in yolov5pytorch:: 100%|██████████| 1168/1168 [00:00<00:00, 6420.04it/s]

# %%
import shutil

# %%
shutil.move("tennis-ball-detection-6/train",
"tennis-ball-detection-6/tennis-ball-detection-6/train",
)
shutil.move("tennis-ball-detection-6/test",
"tennis-ball-detection-6/tennis-ball-detection-6/test",
)
shutil.move("tennis-ball-detection-6/valid",
"tennis-ball-detection-6/tennis-ball-detection-6/valid",
)
# Out:
# 'tennis-ball-detection-6/tennis-ball-detection-6/valid'

# %%
dataset.location
# Out:
# '/content/tennis-ball-detection-6'

# %%
# !yolo task=detect mode=train model=yolov5l6u.pt data={dataset.location}/data.yaml epochs=100 imgsz=640
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...
# Ultralytics 8.4.11 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ```markdown
# # Project Title: Tennis Ball Detection (YOLOv5 Training)
#
# ## Key Results: Visual Comparison
#
# To showcase the model's performance, you would include visual comparisons here. You could take a few images or video frames from your test set, run the trained YOLOv5 model on them, and then display:
#
# *   **Original Image/Frame**: The input image before detection.
# *   **Detection Overlay**: The same image with the model's predicted bounding boxes and confidence scores drawn around the detected tennis balls.
# *   **Ground Truth Overlay (Optional)**: If you have labeled test images, you could also show the ground truth annotations for direct comparison.
#
# This visually demonstrates how well the model identifies tennis balls in various scenarios.
#
# ## Quantitative Results (Evaluation)
#
# To objectively prove the model's effectiveness, the trained YOLOv5 model's performance was evaluated on the validation set using industry-standard metrics, as summarized below. These metrics reflect the model's ability to accurately detect and localize tennis balls.
#
# **Final Epoch (Epoch 100/100) Metrics:**
#
# *   **Precision (P): `0.879`**
#     *   **Explanation**: This means that 87.9% of the objects the model *detected* as tennis balls were actually tennis balls. It reflects the accuracy of positive predictions.
#
# *   **Recall (R): `0.782`**
#     *   **Explanation**: This indicates that the model correctly identified 78.2% of all the actual tennis balls present in the validation images. It measures the model's ability to find all positive instances.
#
# *   **mAP50 (mean Average Precision at IoU=0.5): `0.815`**
#     *   **Explanation**: This is the average precision across all detected classes (in this case, just 'tennis ball'), where a detection is considered correct if its Intersection over Union (IoU) with the ground truth is at least 50%. A score of 0.815 indicates strong performance in detecting tennis balls with reasonable overlap.
#
# *   **mAP50-95 (mean Average Precision averaged over IoU=0.5 to 0.95): `0.352`**
#     *   **Explanation**: This is a more rigorous metric, calculating the average precision across various IoU thresholds, ranging from 50% to 95%. A value of 0.352 suggests that while the model is good at general detection (mAP50), there's room for improvement in very precise localization (getting very tight bounding boxes).
#
# The model demonstrates a good balance of precision and recall, with a strong mAP50 score for general tennis ball detection. The mAP50-95, while lower, is typical for this more challenging metric and can often be improved with further training or data augmentation.
